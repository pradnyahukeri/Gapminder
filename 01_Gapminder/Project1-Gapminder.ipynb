# %%
import pandas as pd

# %%
life = pd.read_excel('gapminder_lifeexpectancy.xlsx', index_col=0)
fert = pd.read_csv('gapminder_total_fertility.csv', index_col=0)

# %%
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
life = life[[1950, 1975, 2000, 2015]]
life.
# Out:
#                         1950   1975  2000  2015
# Life expectancy
# Abkhazia                 NaN    NaN   NaN   NaN
# Afghanistan            26.85  39.61  50.1  53.8
# Akrotiri and Dhekelia    NaN    NaN   NaN   NaN
# Albania                54.48  69.77  74.7  78.0
# Algeria                42.77  55.24  73.3  76.4
# ...                      ...    ...   ...   ...
# Yugoslavia               NaN    NaN   NaN   NaN
# Zambia                 42.85  56.70  44.8  56.7
# Zimbabwe               48.46  59.41  47.9  59.3
# Åland                    NaN    NaN  80.0   NaN
# South Sudan            28.14  42.93  54.4  56.1
#
# [260 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

life[2015].hist()
plt.savefig('histo.png')

# %%
life[2015].hist(bins=30,facecolor='#ff0000',alpha=0.75,histtype='bar')
plt.title('life expectancy')
plt.xlabel('value')
plt.ylabel('frequency')
#plt.axis([0.0, 50.0, 0.0, 10.0])
plt.savefig('histo.png', dpi=150)

# %%
life[1975].hist(bins=10,facecolor='#ffcc00',alpha=0.75,histtype='bar')
plt.title('life expectancy')
plt.xlabel('value')
plt.ylabel('frequency')
plt.savefig('histo_1975.png', dpi=150)

# %%
life[1950].hist(bins=10,alpha=0.75,histtype='bar')
plt.title('life expectancy')
plt.xlabel('value')
plt.ylabel('frequency')
plt.savefig('histo_1950.png', dpi=150)

# %%
life[2000].hist(bins=10,facecolor='#ff00aa',alpha=0.75,histtype='bar')
plt.title('life expectancy')
plt.xlabel('value')
plt.ylabel('frequency')
plt.savefig('histo_2000.png', dpi=150);

# %% [markdown]
# ## Final Milestone

# %%
import pandas as pd
fert=pd.read_csv('gapminder_total_fertility.csv', index_col=0)
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
life=pd.read_excel('gapminder_lifeexpectancy.xlsx',index_col=0)

# %%
print(life.shape)
# Out:
# (260, 217)

# %%
print(fert.shape)
# Out:
# (260, 216)

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
fert.columns=fert.columns.astype(int)
fert.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
fert.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'Åland'],
#       dtype='object', name='Total fertility rate', length=260)

# %%
fert.index.name='country'

# %%
fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# country
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
fert=fert.reset_index()
fert
# Out:
#                    country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0                 Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2    Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                  Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                  Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ..                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 255             Yugoslavia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256                 Zambia  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# 257               Zimbabwe  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# 258                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 259                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
fert = fert.melt(id_vars='country', var_name='year', value_name='fertility_rate')
fert
# Out:
#                      country  year  fertility_rate
# 0                   Abkhazia  1800             NaN
# 1                Afghanistan  1800            7.00
# 2      Akrotiri and Dhekelia  1800             NaN
# 3                    Albania  1800            4.60
# 4                    Algeria  1800            6.99
# ...                      ...   ...             ...
# 56155             Yugoslavia  2015             NaN
# 56156                 Zambia  2015            5.59
# 56157               Zimbabwe  2015            3.35
# 56158                  Åland  2015             NaN
# 56159                  Åland  2015             NaN
#
# [56160 rows x 3 columns]

# %%
life.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'South Sudan'],
#       dtype='object', name='Life expectancy', length=260)

# %%
life.index.name='country'
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# country
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
life = life.reset_index()

# %%
life
# Out:
#                    country   1800   1801   1802   1803   1804   1805   1806  \
# 0                 Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1              Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2    Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                  Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                  Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ..                     ...    ...    ...    ...    ...    ...    ...    ...
# 255             Yugoslavia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 256                 Zambia  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# 257               Zimbabwe  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# 258                  Åland    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 259            South Sudan  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
life = life.melt(id_vars='country', var_name='year', value_name='life expectancy')
life
# Out:
#                      country  year  life expectancy
# 0                   Abkhazia  1800              NaN
# 1                Afghanistan  1800            28.21
# 2      Akrotiri and Dhekelia  1800              NaN
# 3                    Albania  1800            35.40
# 4                    Algeria  1800            28.82
# ...                      ...   ...              ...
# 56415             Yugoslavia  2016              NaN
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56418                  Åland  2016              NaN
# 56419            South Sudan  2016            56.10
#
# [56420 rows x 3 columns]

# %%
pop=pd.read_excel("gapminder_population.xlsx",index_col=0)
pop
# Out:
#                                                    1800       1810       1820  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
# ...

# %%
pop.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'British Indian Ocean Territory', 'Clipperton',
#        'French Southern and Antarctic Lands', 'Gaza Strip',
#        'Heard and McDonald Islands', 'Northern Marianas',
#        'South Georgia and the South Sandwich Islands',
#        'US Minor Outlying Islands', 'Virgin Islands', 'West Bank'],
#       dtype='object', name='Total population', length=275)

# %%
pop.index.name="country"
pop
# Out:
#                                                    1800       1810       1820  \
# country
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
# ...

# %%
pop=pop.reset_index()
pop
# Out:
#                                           country       1800       1810  \
# 0                                        Abkhazia        NaN        NaN
# 1                                     Afghanistan  3280000.0  3280000.0
# 2                           Akrotiri and Dhekelia        NaN        NaN
# 3                                         Albania   410445.0   423591.0
# 4                                         Algeria  2503218.0  2595056.0
# ..                                            ...        ...        ...
# 270                             Northern Marianas        NaN        NaN
# 271  South Georgia and the South Sandwich Islands        NaN        NaN
# 272                     US Minor Outlying Islands        NaN        NaN
# 273                                Virgin Islands        NaN        NaN
# 274                                     West Bank        NaN        NaN
#
#           1820       1830       1840       1850       1860       1870  \
# ...

# %%
pop = pop.melt(id_vars='country', var_name='year', value_name='total population')
pop
# Out:
#                                             country  year  total population
# 0                                          Abkhazia  1800               NaN
# 1                                       Afghanistan  1800         3280000.0
# 2                             Akrotiri and Dhekelia  1800               NaN
# 3                                           Albania  1800          410445.0
# 4                                           Algeria  1800         2503218.0
# ...                                             ...   ...               ...
# 22270                             Northern Marianas  2015               NaN
# 22271  South Georgia and the South Sandwich Islands  2015               NaN
# 22272                     US Minor Outlying Islands  2015               NaN
# 22273                                Virgin Islands  2015               NaN
# 22274                                     West Bank  2015               NaN
#
# [22275 rows x 3 columns]

# %%
df = fert.merge(pop)

# %%
df
# Out:
#                      country  year  fertility_rate  total population
# 0                   Abkhazia  1800             NaN               NaN
# 1                Afghanistan  1800            7.00         3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN               NaN
# 3                    Albania  1800            4.60          410445.0
# 4                    Algeria  1800            6.99         2503218.0
# ...                      ...   ...             ...               ...
# 20974             Yugoslavia  2015             NaN               NaN
# 20975                 Zambia  2015            5.59        16211767.0
# 20976               Zimbabwe  2015            3.35        15602751.0
# 20977                  Åland  2015             NaN               NaN
# 20978                  Åland  2015             NaN               NaN
#
# [20979 rows x 4 columns]

# %%
df=df.merge(life)

# %%
df
# Out:
#                      country  year  fertility_rate  total population  \
# 0                   Abkhazia  1800             NaN               NaN
# 1                Afghanistan  1800            7.00         3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN               NaN
# 3                    Albania  1800            4.60          410445.0
# 4                    Algeria  1800            6.99         2503218.0
# ...                      ...   ...             ...               ...
# 20974             Yugoslavia  2015             NaN               NaN
# 20975                 Zambia  2015            5.59        16211767.0
# 20976               Zimbabwe  2015            3.35        15602751.0
# 20977                  Åland  2015             NaN               NaN
# 20978                  Åland  2015             NaN               NaN
#
#        life expectancy
# 0                  NaN
# 1                28.21
# 2                  NaN
# 3                35.40
# ...

# %%
cont=pd.read_csv("continents.csv",sep=';')
cont
# Out:
#          continent    country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
df_gapminder = df.merge(cont, on=['country'], how='left')
df_gapminder
# Out:
#                      country  year  fertility_rate  total population  \
# 0                   Abkhazia  1800             NaN               NaN
# 1                Afghanistan  1800            7.00         3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN               NaN
# 3                    Albania  1800            4.60          410445.0
# 4                    Algeria  1800            6.99         2503218.0
# ...                      ...   ...             ...               ...
# 20974             Yugoslavia  2015             NaN               NaN
# 20975                 Zambia  2015            5.59        16211767.0
# 20976               Zimbabwe  2015            3.35        15602751.0
# 20977                  Åland  2015             NaN               NaN
# 20978                  Åland  2015             NaN               NaN
#
#        life expectancy continent
# 0                  NaN       NaN
# 1                28.21      Asia
# 2                  NaN       NaN
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_subset = df_gapminder.loc[df_gapminder['year'] == 1970]
#sns.scatterplot(x='life expectancy', y='fertility_rate',size="total population",sizes=(10,2000),hue='continent',data=df_subset, alpha=0.6)
sns.relplot(
    x="life expectancy",
    y="fertility_rate",
    hue="continent",
    col="continent",
    col_wrap=3,
    data=df_subset
)
plt.legend(loc=2, bbox_to_anchor=(1, 1));
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
    df_subset = df_gapminder.loc[df_gapminder['year'] == 1960]
    sns.scatterplot(x='life expectancy', y='fertility_rate',size="total population",sizes=(10,1000),hue='continent',data=df_subset, alpha=0.6)
    plt.axis((0, 90, 0, 10))
    plt.legend(loc=2, bbox_to_anchor=(1, 1))
    plt.title(f'life expectancy v/s fertility_rate 1960')
    lgd = plt.legend(loc=2, bbox_to_anchor=(1, 1))
    plt.savefig(f'lifeexp_{year}.png', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
for year in range(1960,2016):   
    df_subset = df_gapminder.loc[df_gapminder['year'] == year]
    sns.scatterplot(x='life expectancy', y='fertility_rate',size="total population",sizes=(10,1000),hue='continent',data=df_subset, alpha=0.6)
    plt.axis((0, 90, 0, 10))
    plt.legend(loc=2, bbox_to_anchor=(1, 1))
    plt.title(f'life expectancy v/s fertility_rate {year}')
    lgd = plt.legend(loc=2, bbox_to_anchor=(1, 1))
    plt.savefig(f'lifeexp_{year}.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
    plt.close()

# %%
import imageio.v2 as imageio

images = []

for i in range(1960, 2016):
    filename = 'lifeexp_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('output.gif', images, fps=1)

# %% [markdown]
# ### sort data by  population

# %%
df_test=df_gapminder.sort_values(by=['total population'],ascending=False).head(600)

# %%
for year in range(1960,2016):   
    df_subset = df_test.loc[df_test['year'] == year]
    sns.scatterplot(x='life expectancy', y='fertility_rate',size="total population",sizes=(10,1000),hue='country',data=df_subset, alpha=0.6)
    plt.axis((0, 90, 0, 10))
    plt.legend(loc=2, bbox_to_anchor=(1, 1))
    plt.title(f'life expectancy v/s fertility_rate {year}')
    plt.savefig(f'lifeexp_{year}.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
    plt.close()

# %%
import imageio.v2 as imageio

images = []

for i in range(1980,2016):
    filename = 'lifeexp_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('output1.gif', images, fps=1)

# %% [markdown]
# ### Library to view insights

# %%
import ydata_profiling

# %%
ydata_profiling.ProfileReport(df_gapminder)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.1.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-04-28 10:57:14.252811&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
